# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set_theme()

# %%
df = pd.read_csv("tele2_dataset.csv", parse_dates=['date', 'event_time'], )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174185 entries, 0 to 174184
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            174185 non-null  datetime64[ns]
#  1   campaign        174185 non-null  object
#  2   source          174185 non-null  object
#  3   medium          174185 non-null  object
#  4   device          174185 non-null  object
#  5   client_id       174185 non-null  object
#  6   session_id      174185 non-null  int64
#  7   event_time      174185 non-null  datetime64[ns]
#  8   event_name      174185 non-null  object
#  9   current_tariff  47688 non-null   object
#  10  is_LSE_member   47688 non-null   float64
#  11  user_auth       174185 non-null  int64
#  12  user_type       47688 non-null   object
#  13  region_name     174185 non-null  object
#  14  age             174185 non-null  object
#  15  gender          174185 non-null  object
#  16  rfm_index       47688 non-null   float64
#  17  have_home_inet  47688 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(11)
# memory usage: 23.9+ MB

# %%
df.head()
# Out:
#         date                                           campaign  source  \
# 0 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 1 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 2 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 3 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 4 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
#
#   medium   device         client_id           session_id          event_time  \
# 0    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:23:11
# 1    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:49
# 2    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:19
# 3    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:59
# 4    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:21
#
#                                           event_name current_tariff  \
# 0                                            Покупка   Мой разговор
# 1  Клик на кнопку Продолжить 3 (Экран выбора спос...   Мой разговор
# 2                            Ввод контактного номера   Мой разговор
# 3  Клик на кнопку Продолжить 4 (Экран выбора адре...   Мой разговор
# 4                                         Ввод имени   Мой разговор
#
#    is_LSE_member  user_auth user_type region_name          age gender  \
# 0            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 1            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 2            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 3            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 4            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
#
#    rfm_index  have_home_inet
# 0      141.0             0.0
# 1      141.0             0.0
# 2      141.0             0.0
# 3      141.0             0.0
# 4      141.0             0.0

# %%
df.source.value_counts()
# Out:
# source
# (direct)            62324
# google              42777
# yandex.ru           30838
# yandex              22855
# cpagdeslon           4423
#                     ...
# estore-online.ru        1
# sotoper.com             1
# rbc_billboard           1
# link                    1
# rambler.ru              1
# Name: count, Length: 161, dtype: int64

# %%
df.campaign.value_counts()
# Out:
# campaign
# (not set)                                                                           141744
# eshop_art_alw_sim_none_yandex_search_brand-common-tariffs_all-devices_none_rf         4251
# eshop_art_alw_sim_none_yandex_search_brand-shop_all-devices_none_rf                   3259
# 4AQ1                                                                                  2600
# mar_art_flight_flight-8_oct-2022_yandex_search_kpz_all-devices_none_regions           2073
#                                                                                      ...
# mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_vld              1
# cbm_art_alw_premium_none_yandex_search_all_all-devices_none_rf                           1
# mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_rnd                1
# 11_november_lineage                                                                      1
# eshop_art_alw_sim_none_yandex_search_brand-common-delivery_all-devices_test-B_rf         1
# Name: count, Length: 299, dtype: int64

# %%
df.medium.value_counts()
# Out:
# medium
# (none)                  62324
# organic                 46046
# referral                33290
# cpc                     19787
# cpa                     10031
# app                       585
# push_workflow             439
# sms                       213
# formB2B                   181
# push                      170
# programmatic_cpm          146
# chatbot                   137
# video_cpm                 118
# (not set)                 115
# tele2_friends_link        113
# social                     94
# SMS                        67
# b2b_distanc                55
# display_rt_cpm             52
# email                      42
# display_pr_cpm             30
# promopost                  26
# lpt2                       21
# promo                      21
# link                       18
# video_cpm_aug              13
# social_cpm                 11
# audio_cpm                   7
# exchange                    6
# post                        6
# external_link               6
# target                      3
# qr-samoregvideo             2
# vko                         2
# t_khabarovsk                2
# refferal                    1
# display_cpm_bpryansk        1
# programmatic_cpc            1
# email_b2b                   1
# wifi_day                    1
# rtb-cpm                     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174185 entries, 0 to 174184
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            174185 non-null  datetime64[ns]
#  1   campaign        174185 non-null  object
#  2   source          174185 non-null  object
#  3   medium          174185 non-null  object
#  4   device          174185 non-null  object
#  5   client_id       174185 non-null  object
#  6   session_id      174185 non-null  int64
#  7   event_time      174185 non-null  datetime64[ns]
#  8   event_name      174185 non-null  object
#  9   current_tariff  47688 non-null   object
#  10  is_LSE_member   47688 non-null   float64
#  11  user_auth       174185 non-null  int64
#  12  user_type       47688 non-null   object
#  13  region_name     174185 non-null  object
#  14  age             174185 non-null  object
#  15  gender          174185 non-null  object
#  16  rfm_index       47688 non-null   float64
#  17  have_home_inet  47688 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(11)
# memory usage: 23.9+ MB

# %%
df_clients = df[['client_id', 'is_LSE_member', 'user_auth', 'user_type', 'region_name', 'age', 'gender', 'rfm_index', 'have_home_inet']][df['user_auth'] == 1].drop_duplicates(subset=['client_id'])
df_clients['have_home_inet'] = df_clients['have_home_inet'].apply(lambda x: bool(x)) 
df_clients.head()
# Out:
#              client_id  is_LSE_member  user_auth user_type  region_name  \
# 0     117251283.164232            0.0          1       B2C       TYUMEN
# 216  1760047392.166496            0.0          1       B2C  CHELYABINSK
# 296    63759458.166733            1.0          1       B2C         NNOV
# 571   718880971.166721            1.0          1       B2C          SPB
# 608  1664960769.166496            0.0          1       B2C  CHELYABINSK
#
#               age  gender  rfm_index  have_home_inet
# 0     25 - 39 лет    Male      141.0           False
# 216   25 - 39 лет    Male      411.0           False
# 296   25 - 39 лет  Female      122.0           False
# 571  40 - 54 года  Female      241.0           False
# 608   25 - 39 лет  Female      142.0           False

# %%
df_clients.shape
# Out:
# (10381, 9)

# %%
df_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10381 entries, 0 to 174184
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   client_id       10381 non-null  object
#  1   is_LSE_member   10381 non-null  float64
#  2   user_auth       10381 non-null  int64
#  3   user_type       10381 non-null  object
#  4   region_name     10381 non-null  object
#  5   age             10381 non-null  object
#  6   gender          10381 non-null  object
#  7   rfm_index       10381 non-null  float64
#  8   have_home_inet  10381 non-null  bool
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 740.1+ KB

# %%
df_clients.client_id.unique().shape, df_clients.shape
# Out:
# ((10381,), (10381, 9))

# %%
df.age.unique()
# Out:
# array(['25 - 39 лет', '18 - 24 года', '54+', '40 - 54 года', 'До 18 лет'],
#       dtype=object)

# %%
def good_age(age):
    return {'25 - 39 лет': 2, 
    '18 - 24 года': 1, 
    '54+': 4, 
    '40 - 54 года': 3,
    'До 18 лет': 0}[age]

# %%
df_clients.sort_values('age', key=lambda col: col.apply(good_age))[['age', 'have_home_inet', 'gender']]
# Out:
#               age  have_home_inet  gender
# 94974   До 18 лет           False    Male
# 36039   До 18 лет           False  Female
# 163635  До 18 лет           False  Female
# 128696  До 18 лет           False    Male
# 54026   До 18 лет           False  Female
# ...           ...             ...     ...
# 15444         54+           False    Male
# 27928         54+           False  Female
# 15426         54+           False  Female
# 131477        54+           False  Female
# 164278        54+           False  Female
#
# [10381 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.histplot(x=df_clients.sort_values('age', key=lambda col: col.apply(good_age))['age'], ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.histplot(x=df_clients['gender'], ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.histplot(y=df_clients.sort_values('rfm_index')['rfm_index'].apply(lambda x: str(int(x))), binwidth=3,ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 16))
sns.histplot(y=df_clients['region_name'], ax=ax)

plt.show()

# %%
df_clients.sort_values('region_name')
# Out:
#                     client_id  is_LSE_member  user_auth user_type region_name  \
# 167348  1506588972.1669714278            0.0          1       B2C       ALTAI
# 164090  1548619919.1654604870            0.0          1       B2C       ALTAI
# 50290    269478419.1667902225            0.0          1       B2C         ARH
# 165094  1133067434.1666470555            0.0          1       B2C         ARH
# 159428       962802627.166958            0.0          1       B2C         ARH
# ...                       ...            ...        ...       ...         ...
# 93626         374654573.16685            0.0          1       B2C         YAR
# 94812        498831920.166661            1.0          1       B2C         YAR
# 95021       1382158383.166854            1.0          1       B2C         YAR
# 27834       1024512044.166756            0.0          1       B2C         YAR
# 174184   934745616.1669761758            1.0          1       B2C         YAR
#
#                  age  gender  rfm_index  have_home_inet
# 167348  18 - 24 года    Male      243.0            True
# 164090           54+  Female      433.0           False
# 50290      До 18 лет  Female      442.0           False
# 165094  18 - 24 года    Male      343.0           False
# 159428  18 - 24 года    Male      331.0           False
# ...              ...     ...        ...             ...
# 93626    25 - 39 лет  Female      333.0           False
# 94812   18 - 24 года  Female      421.0           False
# 95021   40 - 54 года    Male      422.0            True
# 27834   18 - 24 года    Male      242.0           False
# 174184   25 - 39 лет  Female      312.0           False
#
# [10381 rows x 9 columns]

# %%
df_clients[['region_name', 'user_auth']].groupby('region_name',as_index=False).agg('sum')
# Out:
#    region_name  user_auth
# 0        ALTAI          2
# 1          ARH        105
# 2      BARNAUL         75
# 3     BELGOROD        210
# 4      BRYANSK         77
# ..         ...        ...
# 63   VOLGOGRAD        199
# 64     VOLOGDA         97
# 65    VORONEZH        303
# 66       YANAO         53
# 67         YAR        118
#
# [68 rows x 2 columns]

# %%
'''
fig, ax = plt.subplots(figsize=(8, 8))
sns.displot(data=df_clients[['region_name', 'user_auth']].groupby('region_name',as_index=False).agg('sum'), x='region_name', y='user_auth', binwidth=3,ax=ax)

plt.show()
'''
# Out:
# "\nfig, ax = plt.subplots(figsize=(8, 8))\nsns.displot(data=df_clients[['region_name', 'user_auth']].groupby('region_name',as_index=False).agg('sum'), x='region_name', y='user_auth', binwidth=3,ax=ax)\n\nplt.show()\n"

# %%
df['region_name'].unique()
# Out:
# array(['TYUMEN', 'KHABAROVSK', 'MSK', 'CHELYABINSK', 'BARNAUL', 'NNOV',
#        'VLADIVOSTOK', 'KURSK', 'SPB', 'KAZAN', 'KRASNOYARSK', 'HMAO',
#        'ORENBURG', 'EKT', 'TULA', 'OMSK', 'VLADIMIR', 'NORILSK', 'YANAO',
#        'KUZBASS', 'IRKUTSK', 'ULN', 'ROSTOV', 'KALUGA', 'SARATOV', 'PERM',
#        'MORDOVIA', 'KARELIA', 'ARH', 'KOMI', 'BRYANSK', 'BELGOROD',
#        'KRASNODAR', 'NOVGOROD', 'IVANOVO', 'YAR', 'TAMBOV', 'VORONEZH',
#        'PSKOV', 'KAMCHATKA', 'LIPETSK', 'KURGAN', 'IZHEVSK', 'CHUVASHIA',
#        'NOVOSIBIRSK', 'TVER', 'SMOLENSK', 'BURYATIA', 'SAMARA', 'PENZA',
#        'RYAZAN', 'MURMANSK', 'VOLGOGRAD', 'KOSTROMA', 'TOMSK', 'KIROV',
#        'VOLOGDA', 'MARIEL', 'OREL', 'KALININGRAD', 'KHAKASIA', 'EAO',
#        'SAKHALIN', 'SKYLINKMSK', 'ALTAI', 'MAGADAN', 'SKYLINKSPB',
#        'SKYLINKTVER'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.histplot(y=df.drop_duplicates(['session_id'])['event_name'], ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.histplot(y=df.drop_duplicates(['session_id'], keep='last')['event_name'],ax=ax, color='#47C2F4',)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.histplot(y=df.drop_duplicates(['session_id'], keep='first')['event_name'],ax=ax)

plt.show()

# %%
df_clients.drop_duplicates()
# Out:
#                     client_id  is_LSE_member  user_auth user_type  \
# 0            117251283.164232            0.0          1       B2C
# 216         1760047392.166496            0.0          1       B2C
# 296           63759458.166733            1.0          1       B2C
# 571          718880971.166721            1.0          1       B2C
# 608         1664960769.166496            0.0          1       B2C
# ...                       ...            ...        ...       ...
# 174178  1085561478.1669827294            0.0          1       B2C
# 174180     5638055.1669796789            0.0          1       B2C
# 174181  1171786665.1669820193            0.0          1       B2C
# 174183   346641068.1669795929            0.0          1       B2C
# 174184   934745616.1669761758            1.0          1       B2C
#
#         region_name           age  gender  rfm_index  have_home_inet
# 0            TYUMEN   25 - 39 лет    Male      141.0           False
# 216     CHELYABINSK   25 - 39 лет    Male      411.0           False
# 296            NNOV   25 - 39 лет  Female      122.0           False
# 571             SPB  40 - 54 года  Female      241.0           False
# 608     CHELYABINSK   25 - 39 лет  Female      142.0           False
# ...             ...           ...     ...        ...             ...
# 174178    VOLGOGRAD   25 - 39 лет    Male      443.0           False
# 174180          SPB   25 - 39 лет    Male      332.0           False
# 174181         PERM           54+    Male      213.0           False
# 174183  KRASNOYARSK  18 - 24 года  Female      332.0            True
# 174184          YAR   25 - 39 лет  Female      312.0           False
#
# [10381 rows x 9 columns]

# %%
df.campaign.unique()
# Out:
# array(['eshop_art_alw_sim_none_yandex_search_brand-product-tariffs_all-devices_none_rf',
#        '(not set)',
#        'eshop_art_alw_sim_none_yandex_search_brand-shop_all-devices_none_rf',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_kpz_all-devices_none_regions',
#        'referral_program',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_kpz_all-devices_none_msk',
#        '45812', '99336', '99333', '81074', '742196', '640331',
#        'eshop_art_alw_sim_none_yandex_search_autotargeting_all-devices_none_msk',
#        'eshop_art_alw_sim_none_yandex_search_brand-product-tariff-ustroystvo_all-devices_none_rf',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_general_all-devices_none_regions',
#        'eshop_art_alw_sim_none_yandex_search_brand-product-numbers_all-devices_none_rf',
#        'eshop_art_alw_sim_none_yandex_search_autotargeting_all-devices_none_rf',
#        '52519', '76K20A',
#        'eshop_art_alw_sim_none_yandex_search_brand-product-classic_all-devices_test-A_rf',
#        'mar_art_dop_habarovsk-cl_sep-2022_yandex_search_all_all-devices_none_hab',
#        'mar_art_alw_vfm-birja_none_yandex_search_brand_all-devices_none_rf',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_brand_all-devices_none_regions',
#        'eshop_art_alw_sim_none_yandex_search_brand-common-tariffs_all-devices_none_rf',
#        'eshop_art_alw_mnp_none_yandex_search_autotargeting_all-devices_none_rf',
#        'eshop_art_alw_mnp_none_yandex_search_brand_all-devices_none_rf',
#        'eshop_art_alw_esim_none_yandex_search_brand_desktop_none_rf',
#        'es_art_sim_yandex_search_brand_general_delivery_desktop_rf.78400813',
#        '651359',
#        'eshop_art_alw_sim_none_yandex_search_autotargeting_all-devices_none_regions',
#        'mr_int_zapusk_khabarovsk_comm_2_1022',
#        'digital_art_alw_lk_none_yandex_search_retargeting_all-devices_none_rf',
#        'digital_art_alw_lk_none_yandex_search_brand_all-devices_none_rf',
#        '647825_flocktory_push_ecommerce_regular_no-purchase',
#        'digital_chatbot_orders', '20', 'transfer',
#        'mar_art_alw_vfm-perenos_none_yandex_search_brand_all-devices_none_rf',
#        'eshop_art_alw_sim_none_yandex_search_brand-common-delivery_all-devices_test-A_rf',
#        '92267',
#        'mar_art_dop_habarovsk-cl_sep-2022_yandex_network_all_all-devices_none_hab',
#        '457873', 'mr_int_8flight_1022',
#        'eshop_art_alw_mnp_none_yandex_search_general_all-devices_none_rf',
#        '4AQ1', 'happybirthday', 'mr_int_5flight_0622', 'rtim',
#        'eshop_art_alw_mnp_none_yandex_search_competitors-undecided_all-devices_none_rf',
#        'cashback', '617257',
#        'mr_icn_alw_mobcommerce_market_yandex_search_brand_digital_rf.41037519',
#        'mnp_tele2_ru',
#        'es_icn_sim_yandex_search_all_cpa_delivery_rf.56111784',
#        'mar_art_alw_mobcommerce-market_none_yandex_search_brand_all-devices_none_msk',
#        'eshop_art_alw_sim_none_yandex_search_brand-common_desktop_test-B_msk',
#        'es_icn_sim_yandex_search_brand_general_desktop_msk.41458089.search',
#        'tele2_kms_link',
#        'eshop_art_alw_sim_none_yandex_network_audience_all-devices_Test-A_regions',
#        '253174', '202779', '18_aug_lepim',
#        'eshop_art_alw_sim_none_yandex_search_autotargeting_all-devices_none_spb',
#        '83077', 'market.tele2.ru', '1152572',
#        'es_art_sim_yandex_search_brand_tariffs_delivery_all_rf.78401438',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_general_all-devices_none_regions',
#        'eshop_art_alw_sim_none_yandex_search_brand-product-classic_all-devices_test-B_rf',
#        'mr_int_7flight_0922', 'reg_saratov_IQP1122',
#        'di_icn_alw_lk_yandex_search_keywords_all.36087005', '444796',
#        '18_aug_zapravki',
#        'cpc_eshop_sim_mytarget_63765082,[E-shop][sim][uni][rf][all][14-60][RE][Cart_14d][18.10]',
#        '59240',
#        'cpc_eshop_sim_vk_cid_1025979681,[E-shop][sim][site][rf][all][14-60][RE][ViewContent_30d][24.10',
#        '18_aug_sokolov_old', 'mr_int_4flight_0522',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_prm',
#        'mr_icn_bs_VFM_Birja_yandex_network_rf.78029150',
#        'eshop_art_alw_sim_none_yandex_search_brand-common_mobile_none_msk',
#        '98890', 'mr_affect_mixx_1022', '25491', 'mr_int_reg2_0822',
#        'm_tele2_ru', '450078', 'pilot_tariffs',
#        'eshop_art_alw_sim_none_yandex_search_general_all-devices_none_rf',
#        'eshop_art_alw_sim_none_yandex_search_brand-product-tariffs_desktop_none_msk',
#        'di_icn_alw_lk_yandex_search_retargetingons_all.74861597',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_msk',
#        '630324', 'Z4M1g6',
#        'eshop_art_alw_mnp_none_yandex_search_competitors-decided_all-devices_none_rf',
#        'mr_int_dop_fed4_1022', '1591869', 'zen_wheretobuysim',
#        'mar_art_alw_vfm-birja_none_yandex_network_general_all-devices_none_rf',
#        '640332', '650038_flocktory_push_ecommerce_regular_no-purchase',
#        '637649', 'sp3', 'talk011122',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_general_all-devices_none_msk',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_chb',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_competitors_all-devices_none_regions',
#        'eshop_art_alw_sim_none_yandex_search_brand-common_desktop_test-A_msk',
#        'cbm_art_alw_myconversation_none_yandex_search_all_all-devices_none_rf',
#        'come_to_loyalty_program_more', 'zakazdsim', 'wot-portal',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_rnd',
#        '44143',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_vld',
#        '94653', '599716', '617880',
#        'mar_art_alw_vfm-delgb_none_yandex_search_general_all-devices_none_spb',
#        '25_april_dodoomsk', '19_oct_Sokolov_old',
#        'mar_art_alw_mobcommerce-market_none_yandex_search_brand_all-devices_none_rf',
#        'digital_art_alw_dx_none_yandex_search_brand_all-devices_none_rf',
#        'reg_vladimir_bolshe_0822',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_competitors_all-devices_none_regions',
#        'zen_change_number',
#        'mar_art_alw_vfm_sospaket_yandex_network_all_rf.78396153',
#        'cbm_art_alw_black_none_yandex_search_all_all-devices_none_rf',
#        'online_plus_011122',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_competitors_all-devices_none_spb',
#        'mar_art_flight_flight-7_aug-2022_yandex_search_kpz_all-devices_none_msk',
#        '987285', '58GroY',
#        'mar_art_flight_flight-8_oct-2022_yandex_search_brand_all-devices_none_msk',
#        'eshop_art_flight_esim_sep-2022_yandex_search_all-iphone14_all-devices_none_rf',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_oren',
#        '35Mp', 'cost_of_sim_tele2', '19_oct_old',
#        'sp_int_ponedelniki_1122', 'rtim?mode=webView', 'welcome_3',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_sam',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_bel',
#        'mar_art_alw_vfm-sospaket_none_yandex_search_general_all-devices_none_rf',
#        '243503',
#        'mar_art_alw_vfm-perenos_none_yandex_network_general_all-devices_none_rf',
#        '1576587', 'zen_get_sim',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_brand_all-devices_none_regions',
#        '446491', '185888',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_uss',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_nnov',
#        'mar_art_alw_vfm-delgb_none_yandex_search_brand_all-devices_none_rf',
#        'cbm_art_alw_myonlineplus_none_yandex_search_all_all-devices_none_rf',
#        'affect_mixx_0522', '25_oct_ulibkaradugi',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_hmao',
#        'es_icn_sim_yandex_search_brand_general_delivery_desktop_rf.45380549',
#        'digital_art_alw_lk_none_yandex_search_brand_all-devices_none_all',
#        '600228', 'mr_int_dop_fed2_0522',
#        'cbm_art_alw_myconversation_none_yandex_network_audience_all-devices_none_rf',
#        'mr_int_rouming_0722', 'mycard_tele2_ru', '950576', '91295664',
#        'cpc_eshop_sim_mytarget_63988022,[E-shop][sim][uni][rf][all][14-60][RE][Nastroy_tarif_30d][24.10]',
#        '629077', 'mr_int_6flight_0822',
#        'mar_art_alw_vfm-perenos_none_yandex_network_brand_all-devices_none_rf',
#        '1014983', '11_november_ali_old', '20_sept_adamas',
#        'tariff_my_online_plus', 'mr_int_friends_0822', 'affect_buy_',
#        '570282', 'di_icn_alw_lk_yandex_search_stk.35787700', '96704',
#        'cbm_icn_alw_myconversation_yandex_search_all.51086896',
#        'di_icn_alw_lk_yandex_search_tmn.35787907',
#        'di_icn_alw_lk_yandex_search_lip.35787744',
#        'di_icn_alw_lk_yandex_search_nnov.35787784.search', 'welcome',
#        '644509', '15_sep_SOKOLOV_NEW', 'sp_int_iqp_november_1122',
#        'mar_art_b2b_m2m_none_yandex_search_general_all-devices_none_rf',
#        '100765', '86504', '553844', '20_sept_kari_old',
#        'cpc_eshop_sim_mytarget_63987863,[E-shop][sim][uni][rf][all][14-60][RE][ViewContent_30d+context][24.10]',
#        'mr_icn_dop_fedflight_0522_yandex_network_competitors_rf.74731806',
#        'mar_art_b2b_tarify-konv_none_yandex_search_brand_all-devices_none_rf',
#        'icn_digital_alw_yandex_search_keywords_lk_regions.36087005.search',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_rnd',
#        '178883', '79251',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_kal',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_ekb',
#        'es_art_sim_yandex_search_autotarget_msk.78400912',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_brand_all-devices_none_msk',
#        'black_011122', '5iZB',
#        'eshop_art_alw_sim_none_yandex_network_audience_all-devices_none_rf',
#        '4QsT', '651472',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_spb',
#        '610836',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_nsk',
#        '651984_flocktory_push_ecommerce_regular_no-purchase', 'visitka',
#        '141343', '318319', 'es_icn_sim_yandex_network_video_rf.77886834',
#        'di_icn_alw_lk_yandex_search_bel.35787554', 'qr-samoregvideo',
#        'di_icn_alw_lk_yandex_search_nnov.35787784', '632966',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_tul',
#        '15_sep_SOKOLOV_OLD',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_general_all-devices_none_bel',
#        '648145',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_chel',
#        '651895', '599717',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_krs',
#        '11_november_lineage',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_brand_all-devices_none_irk',
#        'mr_mg__1811',
#        'mar_art_b2b_tarify-traf_none_yandex_search_general_all-devices_none_rf',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_competitors_all-devices_none_msk',
#        'es_icn_sim_yandex_search_brand_general_mobile_msk.48535157',
#        'mar_art_alw_vfm-delgb_none_yandex_network_general_all-devices_none_rf',
#        'mar_art_alw_mobcommerce_market_yandex_search_brand_digital_.78396869',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_sam',
#        '16_nov_komus', '16_nov',
#        'mar_art_dop_ponedelniki_oct-2022_yandex_search_autotargeting_all-devices_none_msk',
#        '15_sep_LitResOLD', 'zen_chat', '112731',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_general_all-devices_none_spb',
#        'eshop_art_alw_sim_none_yandex_search_brand-common-delivery_all-devices_test-B_rf',
#        '11_november_lineage_new', '446490', 'tariff_my_online',
#        'black_171122', 'zen_exchange',
#        'reg_khabarovsk_promo_ponedelniki_2011/',
#        'mar_art_b2b_ats-konv_none_yandex_search_brand_all-devices_none_rf',
#        '1641293', '651482', '82323091', '570801',
#        'mr_int_iqp_mb_msk_1022',
#        'es_icn_sim_yandex_search_brand_general_delivery_desktop_rf.45380549.search',
#        'es_icn_sim_yandex_search_brand_tariffs_mobile_rf.48443259',
#        'cbm_art_alw_premium_none_yandex_search_all_all-devices_none_rf',
#        '652124',
#        'es_icn_sim_yandex_search_brand_numbers_delivery_mobile_rf.48535149',
#        'es_icn_sim_yandex_search_brand_tariffs_mob_msk_cor_ori.74973082',
#        '15712249', 'mr_int_icp_specproect_1122', '651479', '448465',
#        'zen_link_gaming_tariff', 'blackfriday', '20_sept',
#        'es_icn_sim_yandex_search_brand_tariffs_delivery_all_rf.74237763',
#        '98MkXP', 'mr_mg__1611', '651363', '58187635', 'RgGQWL',
#        'talk171122_w_m',
#        'di_icn_alw_lk_yandex_search_keywords_all.36087005.search',
#        '708364', 'mr_icn_4flight_0522_yandex_search_tele2_msk.74624789',
#        'wsms_tgaid_chel',
#        '655895_flocktory_push_ecommerce_regular_no-purchase',
#        '28_nov_kari', 'mr_int_b2b_september_0922', '2506', '651366',
#        'di_art_alw_lk_yandex_search_keywords_all.78402384', '10fh',
#        'eshop_art_alw_sim_none_yandex_all-place_mk_all-devices_none_msk',
#        'eshop_art_alw_sim_none_yandex_search_general-common_all-devices_none_rf',
#        'di_icn_alw_lk_yandex_search_retargeting_all.36598642', 'lk',
#        'mar_art_flight_flight-8_oct-2022_yandex_network_sites_all-devices_none_regions',
#        'eshop_art_alw_sim_none_yandex_search_competitors_all-devices_none_rf',
#        'mar_art_flight_7_aug-2022_yandex_network_brand_all-devices_.78782522',
#        'mar_art_dop_travel_nov-2022_yandex_search_brand_all-devices_none_geocluster'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(8, 24))
sns.histplot(y=df['campaign'],ax=ax)

plt.show()

# %%
df[df['event_name'] == 'Покупка'].shape
# Out:
# (8974, 18)

# %%
df[df['event_name'] == 'Клик на кнопку Перейти к оформлению'].shape
# Out:
# (13958, 18)

# %%
df[(df['event_name'] == 'Покупка') & (df['campaign'] == '(not set)')].shape
# Out:
# (7290, 18)

# %%
7290 / 8974
# Out:
# 0.8123467795854691

# %%
df[df['session_id'] == 5988994287612526860]
# Out:
#          date                                           campaign  source  \
# 0  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 1  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 2  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 3  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 4  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 5  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 6  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 7  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 8  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 9  2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
# 10 2022-11-01  eshop_art_alw_sim_none_yandex_search_brand-pro...  yandex
#
#    medium   device         client_id           session_id          event_time  \
# 0     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:23:11
# 1     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:49
# 2     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:19
# 3     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:59
# 4     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:21
# 5     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:23
# 6     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:45
# 7     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:16:25
# 8     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:21:36
# 9     cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:43
# 10    cpc  desktop  117251283.164232  5988994287612526860 2022-11-01 12:22:10
#
#                                            event_name current_tariff  \
# 0                                             Покупка   Мой разговор
# 1   Клик на кнопку Продолжить 3 (Экран выбора спос...   Мой разговор
# 2                             Ввод контактного номера   Мой разговор
# 3   Клик на кнопку Продолжить 4 (Экран выбора адре...   Мой разговор
# 4                                          Ввод имени   Мой разговор
# 5                                          Ввод email   Мой разговор
# 6   Клик на кнопку Продолжить 2 (Экран выбора реги...   Мой разговор
# 7           Посещение корзины с добавленными товарами   Мой разговор
# 8           Выбор другого тарифа или номера в корзине   Мой разговор
# 9   Клик на кнопку Продолжить 1 (Экран ввода конта...   Мой разговор
# 10                Клик на кнопку Перейти к оформлению   Мой разговор
#
#     is_LSE_member  user_auth user_type region_name          age gender  \
# 0             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 1             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 2             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 3             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 4             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 5             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 6             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 7             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 8             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 9             0.0          1       B2C      TYUMEN  25 - 39 лет   Male
# 10            0.0          1       B2C      TYUMEN  25 - 39 лет   Male
#
#     rfm_index  have_home_inet
# 0       141.0             0.0
# 1       141.0             0.0
# 2       141.0             0.0
# 3       141.0             0.0
# 4       141.0             0.0
# 5       141.0             0.0
# 6       141.0             0.0
# 7       141.0             0.0
# 8       141.0             0.0
# 9       141.0             0.0
# 10      141.0             0.0

# %%
df[(df['event_name'] == 'Покупка') & (df['gender'] == 'Male')].shape
# Out:
# (4428, 18)

# %%
df[(df['event_name'] == 'Покупка') & (df['gender'] == 'Female')].shape
# Out:
# (4546, 18)

# %%
df.drop_duplicates('session_id')['rfm_index'].shape
# Out:
# (30544,)

# %%
df.campaign.dropna().shape
# Out:
# (174185,)

# %%
print('D:\t' * 10000)
# Out:
# D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D:	D ...

# %%
sorted(df['region_name'].unique())
# Out:
# ['ALTAI',
#  'ARH',
#  'BARNAUL',
#  'BELGOROD',
#  'BRYANSK',
#  'BURYATIA',
#  'CHELYABINSK',
#  'CHUVASHIA',
#  'EAO',
#  'EKT',
#  'HMAO',
#  'IRKUTSK',
#  'IVANOVO',
#  'IZHEVSK',
#  'KALININGRAD',
#  'KALUGA',
#  'KAMCHATKA',
#  'KARELIA',
#  'KAZAN',
#  'KHABAROVSK',
#  'KHAKASIA',
#  'KIROV',
#  'KOMI',
#  'KOSTROMA',
#  'KRASNODAR',
#  'KRASNOYARSK',
#  'KURGAN',
#  'KURSK',
#  'KUZBASS',
#  'LIPETSK',
#  'MAGADAN',
#  'MARIEL',
#  'MORDOVIA',
#  'MSK',
#  'MURMANSK',
#  'NNOV',
#  'NORILSK',
#  'NOVGOROD',
#  'NOVOSIBIRSK',
#  'OMSK',
#  'OREL',
#  'ORENBURG',
#  'PENZA',
#  'PERM',
#  'PSKOV',
#  'ROSTOV',
#  'RYAZAN',
#  'SAKHALIN',
#  'SAMARA',
#  'SARATOV',
#  'SKYLINKMSK',
#  'SKYLINKSPB',
#  'SKYLINKTVER',
#  'SMOLENSK',
#  'SPB',
#  'TAMBOV',
#  'TOMSK',
#  'TULA',
#  'TVER',
#  'TYUMEN',
#  'ULN',
#  'VLADIMIR',
#  'VLADIVOSTOK',
#  'VOLGOGRAD',
#  'VOLOGDA',
#  'VORONEZH',
#  'YANAO',
#  'YAR']

# %%
df_clients['rfm_index'].dropna().shape
# Out:
# (10381,)
